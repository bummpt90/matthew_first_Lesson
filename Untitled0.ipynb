# %% [markdown]
# <a href="https://colab.research.google.com/github/bummpt90/matthew_first_Lesson/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
temp = np.array([34, 21.0, 45, 88.3,23.9, 45])
print("My temp: ", temp)
print("The type of Object: ", type(temp))
# Out:
# My temp:  [34.  21.  45.  88.3 23.9 45. ]
# The type of Object:  <class 'numpy.ndarray'>

# %%
import numpy as np
